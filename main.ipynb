# %%
import sys
import os

sys.path .append(os.path.abspath("Codigos"))

# %%
from lectura import leer_imagen, mascara_grises, directorio_imagenes

img_dir = r"C:\Users\delL-\Documents\UPIIT-IPN\Visión Artificial\VA_Proyecto-Final\Datasets\train_images_labels_targets\train\images"

imagenes = directorio_imagenes(img_dir)                                               #Test para comprobar carga de imagenes
print("Total de imagenes encontradas:", len(imagenes))

img = leer_imagen(imagenes[0])
img_gris = mascara_grises(img)
print("Dimensiones de la imagen original:", img.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from lectura import leer_imagen, mascara_grises, directorio_imagenes
#       3 img_dir = r"C:\Users\delL-\Documents\UPIIT-IPN\Visión Artificial\VA_Proyecto-Final\Datasets\train_images_labels_targets\train\images"
#       5 imagenes = directorio_imagenes(img_dir)                                               #Test para comprobar carga de imagenes
#
# ImportError: cannot import name 'directorio_imagenes' from 'lectura' (c:\Users\delL-\Documents\UPIIT-IPN\Visión Artificial\VA_Proyecto-Final\Codigos\lectura.py)
